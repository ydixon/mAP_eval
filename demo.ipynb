# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import pycocotools
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval

import pred_yolo2json
import gt_yolo2json

# %% [markdown]
# # Ground truths

# %%
valid_target_txt = "./5k.txt"
single_target_txt = "single_file.txt"
coco_path = 'coco.names'

# %%
def load_class_names(path):
    with open(path) as f:
        return [line.rstrip("\n") for line in f.readlines()]
    
class_names = load_class_names(coco_path)

# %%
coco_valid_gt_json = 'coco_valid_gt.json'
gt_yolo2json.generate_annotations_file(valid_target_txt, class_names, coco_valid_gt_json)
# Out:
# 100%|██████████| 5000/5000 [00:22<00:00, 225.40it/s]

# %% [markdown]
# # yolo2json

# %%
# result.txt generated by calling ./darknet detector test cfg/coco.data cfg/yolov3.cfg yolov3.weights -thresh 0.001 -dont_show -ext_output < 5k.txt > 5k_result.txt
input_txt = 'result.txt' 

output_json = 'darknet_pred.json'
class_file = 'coco.names'

# %%
pred_yolo2json.write_json(input_txt, output_json, class_file)

# %%
cocoGt = COCO("coco_valid_gt.json")
# cocoGt = COCO(single_file_json)
# Out:
# loading annotations into memory...
# Done (t=0.14s)
# creating index...
# index created!

# %%
resFile = './darknet_pred.json'
cocoDt=cocoGt.loadRes(resFile)
# Out:
# Loading and preparing results...
# DONE (t=3.21s)
# creating index...
# index created!

# %%
imgIds=sorted(cocoDt.getImgIds())
len(imgIds)
# Out:
# 5000

# %%
cocoEval = COCOeval(cocoGt,cocoDt,'bbox')
cocoEval.params.imgIds  = imgIds
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()
# Out:
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=69.09s).
# Accumulating evaluation results...
# DONE (t=8.97s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.307
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.549
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.310
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.416
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.433
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.257
# ...

# %% [markdown]
# # AlexeyAB Darknet Json

# %%
gt_darknet_json = 'coco_valid_gt_mapped_cls_ids.json'
gt_yolo2json.generate_annotations_file(valid_target_txt, class_names, gt_darknet_json, class_ids=gt_yolo2json.COCO_IDS)
# Out:
# 100%|██████████| 5000/5000 [00:22<00:00, 225.71it/s]

# %%
cocoGt = COCO(gt_darknet_json)
# Out:
# loading annotations into memory...
# Done (t=0.11s)
# creating index...
# index created!

# %%
# json obtained by calling ./darknet detector valid cfg/coco.data cfg/yolov3.cfg yolov3.weights
resFile = './darknet_builtin_coco_results.json'
cocoDt=cocoGt.loadRes(resFile)
# Out:
# Loading and preparing results...
# DONE (t=1.54s)
# creating index...
# index created!

# %%
imgIds=sorted(cocoDt.getImgIds())
len(imgIds)
# Out:
# 5000

# %%
cocoEval = COCOeval(cocoGt,cocoDt,'bbox')
cocoEval.params.imgIds  = imgIds
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()
# Out:
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=40.26s).
# Accumulating evaluation results...
# DONE (t=4.65s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.305
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.544
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.309
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.415
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.274
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.415
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.436
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.226
# ...
